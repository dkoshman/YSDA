# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn import datasets

# %%
n_samples = 1500

# %%
circles = datasets.make_circles(n_samples, noise=0.05, factor=0.3)

# %%
plt.scatter(circles[0][:, 0], circles[0][:,1], c=circles[1])

# %%
from sklearn.cluster import KMeans

# %%
clustering = KMeans(n_clusters=2)

# %%
X, y = circles
clustering.fit(X)
# Out:
# KMeans(n_clusters=2)

# %%
plt.scatter(X[:, 0], X[:, 1], c=clustering.labels_, cmap='spring')

# %%
 from sklearn.metrics import adjusted_mutual_info_score

# %%
adjusted_mutual_info_score(y, clustering.labels_)
# Out:
# -0.000353306476169572

# %%
from sklearn.cluster import SpectralClustering

# %%
from sklearn.cluster import SpectralClustering

clustering = SpectralClustering(n_clusters=2, affinity='nearest_neighbors')
clustering.fit(X)
plt.scatter(X[:, 0], X[:, 1], c=clustering.labels_, cmap='spring')
# Out:
# /Applications/anaconda3/lib/python3.8/site-packages/sklearn/manifold/_spectral_embedding.py:245: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"

# %%
from sklearn.cluster import AgglomerativeClustering
from sklearn.neighbors import kneighbors_graph
connectivity = kneighbors_graph(X, n_neighbors = 10)
connectivity = (connectivity + connectivity.T) * 0.5

X[clustering.children_[0][0]]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-52dead9d61bf> in <module>
#       3 connectivity = kneighbors_graph(X, n_neighbors = 10)
#       4 connectivity = (connectivity + connectivity.T) * 0.5
# ----> 5 X[clustering.children_[0][0]]
#
# AttributeError: 'SpectralClustering' object has no attribute 'children_'

# %%
clustering = AgglomerativeClustering(n_clusters=2, linkage='average', connectivity=connectivity)
clustering.fit(X)
plt.scatter(X[:, 0], X[:, 1], c=clustering.labels_, cmap='spring')
# Out:
# C:\Users\Dima\Anaconda3\lib\site-packages\sklearn\cluster\hierarchical.py:418: UserWarning: the number of connected components of the connectivity matrix is 2 > 1. Completing it to avoid stopping the tree early.
#   connectivity, n_components = _fix_connectivity(X, connectivity)

# %%
from sklearn.datasets import load_digits

# %%
digits = load_digits()

# %%
X = digits['data']

# %%
len(X[0]), digits['target']
# Out:
# (64, array([0, 1, 2, ..., 8, 9, 8]))

# %%
plt.imshow(X[9].reshape(8,8), cmap='Greys') #numbers

# %%
clustering = KMeans(n_clusters=10)

# %%
clustering.fit(X)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=10, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
adjusted_mutual_info_score(digits['target'], clustering.labels_)
# Out:
# 0.73874708133202061

# %%
cluster_number=2
for digit, label in list(zip(X, clustering.labels_))[:30]:
    if label == cluster_number:
        plt.imshow(digit.reshape(8,8), cmap='Greys') 
        plt.figure()

# %%
for center in clustering.cluster_centers_: # представитель каждого кластера
    plt.imshow(center.reshape(8,8), cmap='Greys') 
    plt.figure()

# %%
from sklearn.cluster import DBSCAN
clustering=DBSCAN(eps=23)

# %%
clustering.fit(X)
adjusted_mutual_info_score(digits['target'], clustering.labels_)
# Out:
# 0.51806611060942165

# %%
def minvar(prices):
    cov = np.cov((prices[1:] / prices[:-1] - 1).transpose())
    vu = np.array(cov.shape[1] * [1], float)
    num = np.dot(np.linalg.inv(cov), vu)
    den = np.dot(vu, num)
    return num / den

# %%
from zipline.api import (
    history,
    order_target,
    record,
    symbol,
)


def initialize(context):
    context.i = 0


def handle_data(context, data):
    # Skip first 300 days to get full windows
    context.i += 1
    if context.i < 300:
        return

    # Compute averages
    # history() has to be called with the same params
    # from above and returns a pandas dataframe.
    short_mavg = history(100, '1d', 'price').mean()
    long_mavg = history(300, '1d', 'price').mean()

    sym = symbol('AAPL')

    # Trading logic
    if short_mavg[sym] > long_mavg[sym]:
        # order_target orders as many shares as needed to
        # achieve the desired number of shares.
        order_target(sym, 100)
    elif short_mavg[sym] < long_mavg[sym]:
        order_target(sym, 0)

    # Save values for later inspection
    record(AAPL=data[sym].price,
           short_mavg=short_mavg[sym],
           long_mavg=long_mavg[sym])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-33-0b58a0129fd1> in <module>()
# ----> 1 from zipline.api import (
#       2     history,
#       3     order_target,
#       4     record,
#       5     symbol,
#
# ImportError: No module named 'zipline'

# %%
import requests


import pandas as pd
pd.__version__
# Out:
# '0.19.1'
